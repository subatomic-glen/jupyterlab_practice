# %% [markdown]
# We are currently working in the following directory:

# %%
# !pwd
# Out:
# /c/Users/mefde/Documents/data_science_toolkit/jupyterlab_practice

# %% [markdown]
# To time how long it takes to run a Python cell, we could use the timeit command inside a cell as is shown below:

# %%
# %%timeit

for i in range(1_000_000):
    i**2
# Out:
# 166 ms ± 3.41 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# !jupyter nbconvert question-12.ipynb \
    --to html \
    --output=question-12.html \
    --no-input
# Out:
# [NbConvertApp] Converting notebook question-12.ipynb to html
# [NbConvertApp] Writing 271629 bytes to question-12.html
